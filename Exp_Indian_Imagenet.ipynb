# %% [markdown]
# # Creating your own dataset from Google Images
#
# *from: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*.
# Edited by me :)

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button. Then continue scrolling until you cannot scroll anymore. The maximum number of images Google Images shows is 700.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *
import glob

# %%
# %config IPCompleter.greedy=True

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('data/Imagenet_india')
classes = []
for fname in glob.glob('data/Imagenet_india/*'):
    folder = fname.split('_')[-1]
    file = fname.split('/')[-1]
    dest = path/folder
    dest.mkdir(parents=True, exist_ok=True)
    download_images(path/file, dest, max_pics=400)
    classes.append(folder)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:36<00:00]
#     </div>
# Error https://www.littleindia.ca/indian-food-delivery-take-out/wp-content/uploads/2018/09/Samosa.jpg 'content-length'
# Error http://rockingrecipes.com/wp-content/uploads/2018/02/Arabic-samosa-title-main.jpg 'content-length'
# Error https://recipes.timesofindia.com/photo/53723352.cms 'content-length'
# Error https://www.merirasoi.com/wp-content/uploads/2017/08/vegetable-samosa-recipe-780x390.jpg HTTPSConnectionPool(host='www.merirasoi.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/08/vegetable-samosa-recipe-780x390.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')])")))
# Error https://recipes.timesofindia.com/photo/55618405.cms 'content-length'
# Error http://udupi-recipes.com/wp-content/uploads/2017/06/Spicy-and-crispy-samosa.jpg 'content-length'
# Error https://www.chicken.ca/assets/RecipePhotos/_resampled/FillWyIxNDQwIiwiNzAwIl0/Crispy-Samosa-Rolls.jpg 'content-length'
# Error https://www.stayathomemum.com.au/wp-content/uploads/2011/09/Vegetable-Samosas1.jpg 'content-length'
# Error http://vegetarianindianrecipes.com/wp-content/uploads/2016/06/samosa-recipe.jpg 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fcdn-image.foodandwine.com%2Fsites%2Fdefault%2Ffiles%2Fstyles%2Fmedium_2x%2Fpublic%2F201012-xl-samosas.jpg%3Fitok%3DXuqrkTdm&w=1000&c=sc&poi=face&q=70 'content-length'
# Error https://www.196flavors.com/wp-content/uploads/2015/11/samosa-3.jpg 'content-length'
# Error http://tastyrecipes.sapeople.com/files/2017/10/SAMOOSAS-680x510.jpg 'content-length'
# Error https://rukminim1.flixcart.com/image/832/832/jezzukw0/snack-savourie/n/b/p/800-mini-samosa-pack-of-4-pouch-haldiram-s-nagpur-original-imaf3k8n8rzpbcpn.jpeg?q=70 'content-length'
# Error https://minimalistbaker.com/wp-content/uploads/2015/06/10-Ingredient-SAMOSA-inspired-Potato-Cakes-Crispy-on-the-outside-tender-on-the-inside-and-an-easy-glutenfree-version-of-samosas-vegan-glutenfree-recipe-dinner-minimalistbaker.jpg 'content-length'
# Error https://www.afeliaskitchen.com/wp-content/uploads/2017/05/Homemade-Mini-Potato-And-Peas-Samosas-970x610.jpg 'content-length'
# Error https://recipes.timesofindia.com/photo/54016871.cms 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Jain-Samosa.jpg 'content-length'
# Error https://images.financialexpress.com/2018/04/samosa-or-burger.jpg 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Keema-Aloo-Samosa-Sanjeev-Kapoor-Kitchen-FoodFood.jpg 'content-length'
# Error https://www.cookwithkushi.com/wp-content/uploads/2018/11/IMG_0513_.jpg 'content-length'
# Error http://www.pikachakula.com/wp-content/uploads/2018/05/Ndengu-Samosas-002.jpg 'content-length'
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:41<00:00]
#     </div>
# Error http://udupi-recipes.com/wp-content/uploads/2018/01/mallige-idli.jpg 'content-length'
# Error https://www.secondrecipe.com/wp-content/uploads/2017/01/idli.jpg 'content-length'
# Error http://foodofinterest.com/wp-content/uploads/2017/02/Idli.jpg 'content-length'
# Error https://www.yumzen.com/wp-content/uploads/Vegetable-idli_opt.jpg 'content-length'
# Error http://udupi-recipes.com/wp-content/uploads/2017/05/barnyard-millet-idli-goodness-of-millet-683x1024.jpg 'content-length'
# Error https://i0.wp.com/kalimirchbysmita.com/wp-content/uploads/2018/07/Rava-Idli-Insta-01.jpg?resize=1537%2C1024 'content-length'
# Error http://spicesnflavors.com/wp-content/uploads/2017/11/south-indian-chutney-1.jpg 'content-length'
# Error https://img.etimg.com/thumb/msid-63548679,width-600,height-480,resizemode-4/industry/cons-products/food/world-idli-day-2018-quick-facts.jpg 'content-length'
# Error http://udupi-recipes.com/wp-content/uploads/2016/09/tasty-cucumber-idli-using-rava.jpg 'content-length'
# Error https://recipes.timesofindia.com/photo/53554581.cms 'content-length'
# Error https://www.swatirecipe.com/wp-content/uploads/2018/05/idli-sambar-recipe.jpg 'content-length'
# Error http://www.blissofcooking.com/wp-content/uploads/2018/09/Soft-Rice-Idli-Feature.jpg 'content-length'
# Error https://starofmysore.com/wp-content/uploads/2018/05/world-idli-day.jpg 'content-length'
# Error https://img.etimg.com/thumb/msid-63543554,width-640,height-480,imgsize-385176,resizemode-4/initiative-of-a-tamil-nadu-resident.jpg 'content-length'
# Error https://images.inuth.com/2018/03/idli-image.jpg 'content-length'
# Error https://www.kothiyavunu.com/wp-content/uploads/2009/08/Idli.jpg 'content-length'
# Error https://images.inuth.com/2018/03/idli.jpg 'content-length'
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 02:12<00:00]
#     </div>
# Error http://www.madhurasrecipe.com/media/Steamed-Poha-1.jpg 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Kanda-Poha-KhaanaKhazana.jpg 'content-length'
# Error https://recipes.timesofindia.com/photo/53556784.cms 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Kanda_Poha.jpg 'content-length'
# Error https://www.deepikaghare.com/wp-content/uploads/2018/07/%E0%A4%95%E0%A4%BE%E0%A4%82%E0%A4%A6%E0%A4%BE-%E0%A4%AE%E0%A4%B8%E0%A4%BE%E0%A4%B2%E0%A4%BE-%E0%A4%AA%E0%A5%8B%E0%A4%B9%E0%A4%BE-Masala-Poha-Recipe-in-Hindi-1080x608.jpg 'content-length'
# Error https://www.diyworthy.com/wp-content/uploads/2014/12/Kanda-Batata-Poha-Recipe-Image-.jpg 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Poha.jpg 'content-length'
# Error https://recipes.timesofindia.com/photo/60306148.cms 'content-length'
# Error http://www.homefoodforever.com/wp-content/uploads/2017/12/Indore-special-steamed-poha.jpg 'content-length'
# Error https://www.placeoforigin.in/media/catalog/product/cache/1/image/1200x1200/c76ea3ffbe4a25484f8eac86ff255564/n/a/namkb204.jpg 'content-length'
# Error https://www.yumzen.com/wp-content/uploads/simple-poha_opt.jpg 'content-length'
# Error http://www.myhomemantra.com/wp-content/uploads/2012/11/kande_pohe.jpg 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Quinoa-Poha.jpg 'content-length'
# Error http://www.sliceofmylyfe.com/wp-content/uploads/2017/06/1024-x1024-4.jpg 'content-length'
# Error http://www.recipris.com/wp-content/uploads/2012/08/poha17.jpg 'content-length'
# Error http://www.madhurasrecipe.com/media/Steamed-Poha-2.jpg 'content-length'
# Error https://rukminim1.flixcart.com/image/832/832/j3orcsw0/ready-meal/u/v/r/60-mtr-regular-poha-mtr-foods-original-imaeuqrzywqfgnab.jpeg?q=70 'content-length'
# Error http://udupi-recipes.com/wp-content/uploads/2017/05/sajjige-baji-upma-poha.jpg 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Paneer-Poha-Sanjeev-Kapoor-Kitchen-FoodFood.jpg 'content-length'
# Error https://www.placeoforigin.in/media/catalog/product/cache/1/image/1200x1200/c76ea3ffbe4a25484f8eac86ff255564/n/a/namkb056.jpg 'content-length'
# Error https://yummydiaries.com/wp-content/uploads/2017/04/Indori-Poha-1024x739.jpg 'content-length'
# Error https://i0.wp.com/www.exploreflavours.com/wp-content/uploads/2018/02/vegetable-poha-e1519246328837.jpg?resize=960%2C1280&ssl=1 'content-length'
# Error https://i1.wp.com/www.shilpakakitchen.com/wp-content/uploads/2017/07/Gajar-Ka-Halwa.jpg?resize=720%2C405 'content-length'
# Error https://c8.alamy.com/comp/S1RHWF/gajar-ka-halwa-S1RHWF.jpg 'content-length'
# Error https://www.thebengalirecipe.com/images/desserts_drinks_n_chutneys/DES003_gajorer_haluwa/gajar_ka_halwa_s6.jpg 'content-length'
# Error https://i1.wp.com/www.faridascookbook.com/wp-content/uploads/2017/11/Gajar-halwa.png?resize=696%2C1044&ssl=1 'content-length'
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:54<00:00]
#     </div>
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=343457232769420 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=890199974420606 'content-length'
# Error https://www.littleindia.ca/indian-food-delivery-take-out/wp-content/uploads/2018/09/Papadam.jpg 'content-length'
# Error https://cdn2.id.orstatic.com/userphoto/photo/1/1H7/00AIEXB03E642F0BE0B6DEpx.jpg 'content-length'
# Error https://fscomps.fotosearch.com/compc/CSP/CSP502/fried-papadam-isolated-picture__k5024567.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=353600888421721 'content-length'
# Error https://www.barewalls.com/comp/art-print-poster/bwc14395326/biryani-mutton-rice-papadam-with-traditional-background.jpg?ph=10.0&pw=8.0&print_border=0.5&fit=false&flip=false&stretch_to_fit=false&print_colorfilter=no_filter&bits=&side_style=&units=&frame_id=0&frame_type=custom&show_banner=true&artist_attr_name=false&artist_attr_show=false&artist_attr_title=false&artist_attr_format=&artist_attr_font=&artist_attr_size=&custom_x_pct=&custom_y_pct=&custom_w_pct=&custom_h_pct=&bleed_size=&is_custom=false&can_edit_frame=true&object_width=8.0&object_height=10.0&fit_select=False&m1=-1&m2=-1 'content-length'
# Error https://c8.alamy.com/comp/MF7H4N/curry-dish-with-cauliflower-butternut-pumpkin-spinach-and-coriander-papadam-and-rice-MF7H4N.jpg 'content-length'
# Error http://jlhrestaurant.com/wp-content/uploads/2018/06/Plate-of-Papadam.jpg 'content-length'
# Error https://fscomps.fotosearch.com/compc/CSP/CSP992/delicious-papadam-stock-photography__k13580850.jpg 'content-length'
# Error http://l7.alamy.com/comp/X7K622/papadam-papadum-X7K622.jpg 'content-length'
# Error http://alfinimpex.com/images/plain.jpg HTTPConnectionPool(host='alfinimpex.com', port=80): Max retries exceeded with url: /images/plain.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f53f0d9e668>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error http://elakkiaonline.com/image/data/Niru%20Replacement%20images/150gbrand%20papadam.jpg ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error http://globalfoodcity.com/wp-content/uploads/2018/01/Baby-Papadam.jpg 'content-length'
# Error http://l7.alamy.com/comp/XDFT74/delicious-papadam-XDFT74.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=375124862941620 'content-length'
# Error https://c8.alamy.com/comp/XEEXD5/coconut-rice-indian-recipe-food-served-with-spices-and-papadam-XEEXD5.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1515523441870343 'content-length'
# Error https://burpple-3.imgix.net/foods/1841e366b4629d6ba66727021_original.?w=645&dpr=1&fit=crop&q=80 'content-length'
# Error https://static7.orstatic.com/userphoto/photo/5/47L/00TXY624CE8A0743555D20px.jpg ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')])")))
# Error http://www.emmaslittlekitchen.com/wp-content/uploads/2014/10/IMG_4697.jpg 'content-length'
# Error https://www.shophealthy.in/image/cache/sellers/4862/Organic-Black-Pepper-1-1000x1000.jpg 'content-length'
# Error http://www.pngall.com/wp-content/uploads/2018/04/Black-Pepper-High-Quality-PNG.png 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fcdn-img.health.com%2Fsites%2Fdefault%2Ffiles%2Fstyles%2Fmedium_16_9%2Fpublic%2Fstyles%2Fmain%2Fpublic%2Fbig-black-pepper-400x400.jpg%3Fitok%3D4MTJw5tF&w=800&q=70 'content-length'
# Error https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fcdn-image.foodandwine.com%2Fsites%2Fdefault%2Ffiles%2Fstyles%2Fmedium_2x%2Fpublic%2Fchinese-long-beans-with-cracked-black-pepper.jpg%3Fitok%3DYPaZpWTt&w=1000&c=sc&poi=face&q=70 'content-length'
# Error http://thaifoodhouse.in/wp-content/uploads/2016/06/salmon-black-pepper.jpg 'content-length'
# Error https://images.financialexpress.com/2017/04/pepper-PTI.jpg 'content-length'
# Error https://homemademyway.com/product_images/uploaded_images/blackpepper-corn.jpg 'content-length'
# Error https://www.shophealthy.in/image/cache/sellers/26688/Geo-Fresh-Organic-Black-Pepper-440g-USDA-Certified-9131-1000x1000.jpeg 'content-length'
# Error https://www.organicfacts.net/wp-content/uploads/2013/06/Blackpepper.jpg 'content-length'
# Error https://cdn.shopclues.com/images/thumbnails/53800/320/320/BlackPepper1485085081.jpg 'content-length'
# Error https://3nfr102dprzc31n0e92qcsd1-wpengine.netdna-ssl.com/wp-content/uploads/black_pepper_hero1.jpg 'content-length'
# Error https://www.delightfoods.com/media/catalog/product/cache/1/image/1100x1100/9df78eab33525d08d6e5fb8d27136e95/b/l/blackpepper1.jpg 'content-length'
# Error https://img.etimg.com/thumb/msid-25721264,width-1200,height-900,imgsize-17635,overlay-etmarkets/photo.jpg 'content-length'
# Error https://www.thehindubusinessline.com/economy/agri-business/7zdbak/article25041702.ece/alternates/WIDE_660/BL26-BLACKPEPPER2 'content-length'
# Error https://rukminim1.flixcart.com/image/832/832/jh80ia80/spice-masala/h/3/e/175-spice-hub-100-pure-whole-black-pepper-kali-mirchi-malabar-original-imaf588thhtzqg3s.jpeg?q=70 'content-length'
# Error http://www.earthexpocompany.com/images/products/black-pepper/Black-pepper-crushed.jpg 'content-length'
# Error https://balconygardenweb.com/wp-content/uploads/2015/10/how-to-grow-black-pepper_mini.jpg 'content-length'
# Error http://arleycakes.com/wp-content/uploads/2016/03/Arley-Arrington_24-1024x683.jpg ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 03:38<00:00]
#     </div>
# Error https://cdn.shopclues.com/images1/thumbnails/91318/320/320/140347763-91318568-1534578935.jpg 'content-length'
# Error https://d5nkxbcmx4bo4.cloudfront.net/faceview/bb/gc/h9g/ae/affimgs/az-large-4766211.jpg HTTPSConnectionPool(host='d5nkxbcmx4bo4.cloudfront.net', port=443): Max retries exceeded with url: /faceview/bb/gc/h9g/ae/affimgs/az-large-4766211.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f53f0e735c0>: Failed to establish a new connection: [Errno -5] No address associated with hostname'))
# Error https://cdn.shopclues.com/images1/thumbnails/91317/320/320/140347548-91317943-1534574924.jpg 'content-length'
# Error https://d5nkxbcmx4bo4.cloudfront.net/faceview/e3d/fb/a5j/a7b/affimgs/az-large-1095143.jpg HTTPSConnectionPool(host='d5nkxbcmx4bo4.cloudfront.net', port=443): Max retries exceeded with url: /faceview/e3d/fb/a5j/a7b/affimgs/az-large-1095143.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f53f0e73f60>: Failed to establish a new connection: [Errno -5] No address associated with hostname'))
# Error http://saisaibatake.ame-zaiku.com/gakki/gakki_image/aulos.jpg 'content-length'
# Error https://www.maxpixel.net/static/photo/1x/Flute-Musical-Instrument-Instrument-Music-Classic-2833897.jpg 'content-length'
# Error https://www.drawingtutorials101.com//drawing-tutorials/Others/Musical-Instruments/flute/how-to-draw-Flute-step-0.png 'content-length'
# Error https://www.matthewsmuziek.nl/media/wysiwyg/homepage/flute1.jpg 'content-length'
# Error https://kassa.imgix.net/KS-GS-105.jpg?w=1201 'content-length'
# Error https://brasswindinstruments.com/wp-content/uploads/2017/11/224-48009700a16652e0ad33e4633c80b40e-300x300.jpg HTTPSConnectionPool(host='brasswindinstruments.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/11/224-48009700a16652e0ad33e4633c80b40e-300x300.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f53f0da9898>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error https://www.matthewsmuziek.nl/media/catalog/product/cache/2/small_image/400x/9df78eab33525d08d6e5fb8d27136e95/e/a/eastman-beginner-flute-thumbnail.jpg 'content-length'
# Error https://d5nkxbcmx4bo4.cloudfront.net/faceview/d3e/b9c/hj/ac/affimgs/az-large-2791234.jpg HTTPSConnectionPool(host='d5nkxbcmx4bo4.cloudfront.net', port=443): Max retries exceeded with url: /faceview/d3e/b9c/hj/ac/affimgs/az-large-2791234.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f53f0dfd4e0>: Failed to establish a new connection: [Errno -5] No address associated with hostname'))
# Error http://musicalmentorsandmore.com/wp-content/uploads/2015/08/68314834.jpg 'content-length'
# Error https://www.thatnext4years.com/wp-content/uploads/2017/08/Depositphotos_89576214_l-2015-1200x808.jpg 'content-length'
# Error https://www.superprof.co.in/images/teachers/teacher-home-teach-flute-clarinet-and-saxophone-and-all-woodwind-instruments-lets-make-music.jpg 'content-length'
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:36<00:00]
#     </div>
# Error https://c8.alamy.com/comp/F9KKNH/saraswati-vina-or-saraswathi-veena-a-musical-instrument-india-F9KKNH.jpg 'content-length'
# Error https://i2.wp.com/antiquedale.com/wp-content/uploads/2017/11/Prod173-2.jpg?fit=530%2C801 'content-length'
# Error https://c8.alamy.com/comp/F3FY98/lady-playing-veena-south-indian-musical-instrument-india-hma-127902-F3FY98.jpg 'content-length'
# Error https://www.drawingtutorials101.com/drawing-tutorials/Others/Musical-Instruments/veena/how-to-draw-Veena-step-0.png 'content-length'
# Error https://c8.alamy.com/comp/F9KKNG/saraswati-vina-or-saraswathi-veena-a-musical-instrument-india-F9KKNG.jpg 'content-length'
# Error http://www.forbesindia.com/fbimages/800x600/proportional/jpeg/media/images/2012/Apr/img_64768_veena_sm.jpg 'content-length'
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 01:06<00:00]
#     </div>
# Error http://carnivalmunchies.com/wp-content/uploads/2015/10/appam.jpg 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Appam.jpg 'content-length'
# Error https://www.kothiyavunu.com/wp-content/uploads/2009/08/IMG_7608-514x771.jpg 'content-length'
# Error http://anishyaskitchen.com/wp-content/uploads/2017/02/Appam-Chammanthi.jpg 'content-length'
# Error https://www.sanjeevkapoor.com/UploadFiles/RecipeImages/Soji-Appam.jpg 'content-length'
# Error http://taste.tdzire.com/wp-content/uploads/2013/04/1210.jpg 'content-length'
# Error http://www.handfulofrecipes.com/wp-content/uploads/2013/06/IMG_6595.jpg 'content-length'
# Error https://www.cookawesome.com/wp-content/uploads/2016/05/Chicken-Stew-and-Appam.jpg 'content-length'
# Error http://udupi-recipes.com/wp-content/uploads/2017/06/Filling-breakfast-instant-rava-appam.jpg 'content-length'
# Error http://shravskitchen.com/wp-content/uploads/2017/07/Kerala-appam-4-683x1024. HTTPConnectionPool(host='shravskitchen.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017/07/Kerala-appam-4-683x1024. (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f53f0d9efd0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
# Error https://whatanindianrecipe.com/wp-content/uploads/2011/12/P1080105.jpg HTTPSConnectionPool(host='whatanindianrecipe.com', port=443): Max retries exceeded with url: /wp-content/uploads/2011/12/P1080105.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f53f0524c88>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error http://www.handfulofrecipes.com/wp-content/uploads/2012/12/appam-animation-2.gif 'content-length'
# Error https://nishkitchen.com/wp-content/uploads/2015/04/pesaha-appam-paal.jpg 'content-length'
# Error https://img.etimg.com/thumb/msid-57375885,width-643,imgsize-28164,resizemode-4/from-charcoal-appam-to-carbon-sushi-black-is-the-new-colour-of-food.jpg 'content-length'
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:33<00:00]
#     </div>
# Error https://c8.alamy.com/comp/CFGXE6/himalayan-monal-pheasant-CFGXE6.jpg 'content-length'
# Error http://www.nationalpedia.com/wp-content/uploads/2017/03/National-Bird-of-Nepal.png 'content-length'
# Error https://c8.alamy.com/comp/EKK9ED/female-himalayan-monal-pheasant-lophophorus-impejanus-aka-impeyan-EKK9ED.jpg 'content-length'
# Error https://steemitimages.com/0x0/https://anilblonnepal.files.wordpress.com/2015/07/national-bird-of-nepal-danphe.jpg?w=812 'content-length'
# Error https://c8.alamy.com/comp/CWF3KP/a-beautiful-himalayan-monal-bird-head-closeup-CWF3KP.jpg 'content-length'
# Error https://c8.alamy.com/comp/FP4DE8/himalayan-monal-lophophorus-impejanus-female-sagarmatha-national-park-FP4DE8.jpg 'content-length'
# Error http://animamundimag.com/wp-content/uploads/2017/11/Schermata-2017-10-08-alle-17.21.54.jpg 'content-length'
# Error http://humour.amulyam.com/images/humour/large/1211/161631.jpg 'content-length'
# Error https://static3.bigstockphoto.com/1/4/8/large1500/84192272.jpg 'content-length'
# Error https://c7.alamy.com/comp/X9TP4E/himalayan-monal-pheasant-X9TP4E.jpg 'content-length'
# Error http://www.birdsofindia.org/media_images/2017/467_1041-130-5a09a902f007e-1.jpg 'content-length'
# Error https://comps.gograph.com/himalayan-monal-or-lophophorus-impejanus-vintage-engraving_gg58294188.jpg 'content-length'
# Error https://fscomps.fotosearch.com/compc/CSP/CSP412/male-himalayan-monal-lophophorus-pictures__k4123808.jpg 'content-length'
# Error http://zoogalaxy.net/assets/images/aves/galliformes/phasianidae/lophophorus-impejanus/lophophorus-impejanus_01_zoogalaxy.jpg 'content-length'
# Error http://www.indiatourisminfo.in/wp-content/uploads/2016/12/himalayan-monal.jpg 'content-length'
# Error https://www.pixoto.com/images-photography/animals/birds/himalayan-monal-98745013.jpg 'content-length'
# Error https://c8.alamy.com/comp/HM82FF/male-himalayan-monal-lophophorus-impejanus-at-kedarnath-wildlife-sanctuary-HM82FF.jpg 'content-length'
# Error https://www.featheremporium.com/images/pheasants/impeyan/skins/imp750-new.jpg 'content-length'
# Error https://www.domesticforest.com/wp-content/uploads/2018/10/778px-Himalayan_Monal_Female_16880438716.jpg 'content-length'
# Error https://images.jagran.com/naidunia/surkhab_11_07_2016.jpg 'content-length'
# Error https://c8.alamy.com/comp/A4D0N1/himalayan-monal-lophophorus-impeyanus-male-captive-A4D0N1.jpg 'content-length'
# Error https://static2.bigstockphoto.com/1/4/8/large1500/84192221.jpg 'content-length'
# Error https://www.pixoto.com/images-photography/animals/birds/himalayan-monal-4798736022634496.jpg 'content-length'
# Error https://fineartamerica.com/images/artworkimages/medium/1/himalayan-monal-pheasant-jennie-robin.jpg 'content-length'
# Error https://images.jagran.com/naidunia/monal_11_07_2016.jpg 'content-length'
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 01:12<00:00]
#     </div>
# Error https://a.ctimg.net/1hAqvM67Rbuq2_RRJnLTRg/north-indian-style-chana-masala-chickpea-curry-recipe.1024x1024.jpg HTTPSConnectionPool(host='a.ctimg.net', port=443): Max retries exceeded with url: /1hAqvM67Rbuq2_RRJnLTRg/north-indian-style-chana-masala-chickpea-curry-recipe.1024x1024.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f53f0d9df98>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error https://minimalistbaker.com/wp-content/uploads/2016/02/AMAZING-Chana-Masala-made-in-1-Pot-So-healthy-flavorful-and-delicious-vegan-glutenfree-chanamasala-recipe-minimalistbaker.jpg 'content-length'
# Error http://www.spicechronicles.com/wp-content/uploads/2014/08/sq600.jpg 'content-length'
# Error https://cookieandkate.com/images/2014/03/quick-vegan-chana-masala-320x180.jpg 'content-length'
# Error http://vegansparkles.com/wp-content/uploads/2013/09/Eggplant-Chana-Masala-1.jpg 'content-length'
# Error http://www.secondrecipe.com/wp-content/uploads/2018/03/channa-masala-feb-2018.jpg 'content-length'
# Error http://glebekitchen.com/wp-content/uploads/2017/03/chanamasalafront-2.jpg 'content-length'
# Error http://smashedpeasandcarrots.com/wp-content/uploads/2017/02/Instant-Pot-Chana-Masala.jpg 'content-length'
# Error https://www.peta.org.uk/wp-content/uploads/2017/06/indian_chana_masala.png 'content-length'
# Error https://www.usnews.com/dims4/USNEWS/009b318/2147483647/thumbnail/640x420/quality/85/?url=http%3A%2F%2Fmedia.beam.usnews.com%2F54%2F37161e12f631ea9fc67fb7cfc089b6%2Fresizes%2F1500%2Fmedia%3A9cee57a1aa134997afed780252b03e49India_Rhinos_27689.jpg 'content-length'
# Error http://www.freeinfosociety.com/chimage.php?image=science/indianrhinoceros.jpg 'content-length'
# Error x-raw-image:///d07d76ac1c491226148287924cb0de4bfaa0877d8fbb9dd1d853ec00d7a293ef No connection adapters were found for 'x-raw-image:///d07d76ac1c491226148287924cb0de4bfaa0877d8fbb9dd1d853ec00d7a293ef'
# Error https://images.financialexpress.com/2017/08/rhino.jpg 'content-length'
# Error http://www.inkart.net/images/large_images/indian_rhinoceros.jpg 'content-length'
# Error x-raw-image:///f4e70728f9e7767e308819125b2a577412e4e8e813430d195f0010389098c708 No connection adapters were found for 'x-raw-image:///f4e70728f9e7767e308819125b2a577412e4e8e813430d195f0010389098c708'

# %%
len(classes)
# Out:
# 46

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# samosa
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='379' class='' max='379', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [379/379 00:11<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000082.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000336.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000172.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000045.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000238.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000236.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000049.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000228.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/samosa/00000355.jpg'
# Idli
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='383' class='' max='383', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [383/383 00:10<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000142.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000151.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000211.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000251.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000338.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000286.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000162.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000262.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/Idli/00000384.jpg'
# poha
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='372' class='' max='372', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [372/372 00:10<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000086.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000173.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000212.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000372.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000060.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000304.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000318.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000399.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000256.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/poha/00000329.jpg'
# halwa
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='377' class='' max='377', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [377/377 00:10<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000047.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000327.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000119.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000084.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000166.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000190.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000156.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/halwa/00000214.jpg'
# papadam
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='364' class='' max='364', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [364/364 00:07<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000248.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000382.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000359.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000083.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000138.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000231.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000110.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000098.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000040.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000304.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000269.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000191.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/papadam/00000393.jpg'
# harmonium
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='352' class='' max='352', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [352/352 00:07<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000019.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000290.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000349.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000084.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000045.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000055.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000324.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000269.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000062.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/harmonium/00000259.jpg'
# pepper
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='374' class='' max='374', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [374/374 00:08<00:00]
#     </div>
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000160.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000041.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000083.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000381.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000213.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000217.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000333.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000255.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000386.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000317.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000133.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000153.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000180.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000269.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/pepper/00000177.jpg'
# flute
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='385' class='' max='385', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [385/385 00:08<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000300.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000145.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000204.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000032.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000237.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000174.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000019.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000041.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000224.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000389.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000063.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000333.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000251.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000202.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000055.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000087.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000249.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000026.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000283.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000384.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000356.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000062.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/flute/00000313.jpg'
# veena
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='375' class='' max='375', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [375/375 00:07<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000205.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000047.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000396.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000373.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000135.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000337.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000333.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000301.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000126.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000319.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000344.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000031.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000108.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000006.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000253.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/veena/00000305.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# SarusCrane
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='371' class='' max='371', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [371/371 00:08<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/SarusCrane/00000079.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/SarusCrane/00000244.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/SarusCrane/00000067.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/SarusCrane/00000238.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/SarusCrane/00000077.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/SarusCrane/00000245.jpg'
# appam
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='386' class='' max='386', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [386/386 00:09<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/appam/00000146.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/appam/00000364.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8589934590 bytes but only got 6252. Skipping tag 34855
#   " Skipping tag %s" % (size, len(data), tag))
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/appam/00000278.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/appam/00000058.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/appam/00000067.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/appam/00000399.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/appam/00000306.jpg'
# molan
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='375' class='' max='375', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [375/375 00:09<00:00]
#     </div>
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 4568514560 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2449997824 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 10877140992 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 8.
#   warnings.warn(str(msg))
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/molan/00000255.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet
jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/payasam/00000278.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/payasam/00000272.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/payasam/00000110.jpg'
# koel
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='365' class='' max='365', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [365/365 00:09<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/koel/00000378.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/koel/00000179.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/koel/00000118.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/koel/00000098.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/koel/00000048.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# dosa
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='381' class='' max='381', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [381/381 00:11<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/dosa/00000292.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/dosa/00000110.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/dosa/00000238.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/dosa/00000249.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/dosa/00000206.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/dosa/00000385.jpg'
# roti
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='386' class='' max='386', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [386/386 00:09<00:00]
#     </div>
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/roti/00000204.jpg'
# ...
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000145.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000248.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000099.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000364.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000246.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000075.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000136.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000045.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000030.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000344.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000210.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000162.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000106.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/chilli/00000080.jpg'
# jalebi
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='375' class='' max='375', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [375/375 00:09<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000024.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000277.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000185.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000027.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000356.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000156.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000305.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/jalebi/00000252.jpg'
# gulabjamun
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='380' class='' max='380', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [380/380 00:10<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000300.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000135.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000381.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000251.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000105.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000303.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000391.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000367.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000163.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/gulabjamun/00000155.jpg'
# hawamahal
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='360' class='' max='360', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [360/360 00:09<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/hawamahal/00000076.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/hawamahal/00000114.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/hawamahal/00000035.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/hawamahal/00000037.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/hawamahal/00000071.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/hawamahal/00000270.jpg'
# CommonTailorbird
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='374' class='' max='374', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [374/374 00:07<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/CommonTailorbird/00000054.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 6.
#   warnings.warn(str(msg))
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/CommonTailorbird/00000223.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/CommonTailorbird/00000098.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/CommonTailorbird/00000297.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 6.
#   warnings.warn(str(msg))
# eagle
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='388' class='' max='388', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [388/388 00:08<00:00]
#     </div>
# ginger
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='372' class='' max='372', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [372/372 00:08<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000147.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000127.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000332.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000220.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000226.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000109.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000144.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000041.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000103.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000299.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000083.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000131.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000314.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000123.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000159.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000394.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000242.jpg'
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000328.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000323.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000325.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000175.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000235.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000399.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000048.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/ginger/00000320.jpg'
# rasgula
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='375' class='' max='375', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [375/375 00:08<00:00]
#     </div>
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000292.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000179.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000285.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000024.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000217.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000051.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000331.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000317.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000250.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000087.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000232.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000384.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000166.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000097.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000074.jpg'
# cannot identify image file '/home/nbuser/courses/fast-ai/course-v3/nbs/dl1/data/Indian_Imagenet/rasgula/00000270.jpg'

# %% [markdown]
# ## View data

# %%
path = Path('data/Indian_Imagenet')

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /home/nbuser/.anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 6.
#   warnings.warn(str(msg))

# %%
data.classes
# Out:
# ['CommonTailorbird',
#  'Idli',
#  'LangurColobinae',
#  'SarusCrane',
#  'Tiger',
#  'appam',
#  'buffalo',
#  'chilli',
#  'cinnamon',
#  'dosa',
#  'eagle',
#  'flute',
#  'garlic',
#  'ginger',
#  'gulabjamun',
#  'halwa',
#  'harmonium',
#  'hawamahal',
#  'jalebi',
#  'kajukatli',
#  'koel',
#  'lion',
#  'masala',
#  'mint',
#  'models',
#  'molan',
#  'papadam',
#  'payasam',
#  'peacock',
#  'pepper',
#  'poha',
#  'pulsar',
#  'qutubminar',
#  'rasgula',
#  'rhinoceros',
#  'roller',
#  'roti',
#  'sambhar',
#  'samosa',
#  'scorpio',
#  'splendor',
#  'tabla',
#  'tajmahal',
#  'veena',
#  'wolf']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (45, 11959, 3049)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=accuracy)

# %%
learn.fit_one_cycle(5)
# Out:
# Total time: 16:51
# epoch  train_loss  valid_loss  accuracy
# 1      1.019168    0.579156    0.839620  (03:31)
# 2      0.687437    0.452214    0.875697  (03:18)
# 3      0.518458    0.432148    0.883240  (03:26)
# 4      0.415156    0.399927    0.894392  (03:18)
# 5      0.370346    0.394040    0.896031  (03:17)

# %%
learn.save('stage-1')

# %%
learn.load('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-5,1e-4))
# Out:
# Total time: 13:33
# epoch  train_loss  valid_loss  accuracy
# 1      0.339516    0.385503    0.893736  (03:24)
# 2      0.314108    0.370910    0.903247  (03:23)
# 3      0.263079    0.356459    0.905871  (03:25)
# 4      0.218501    0.350917    0.906527  (03:20)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(figsize=(20,20))

# %%
interp.plot_top_losses(25, figsize=(16,16))
